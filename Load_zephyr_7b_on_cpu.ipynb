# %%
# !pip install ctransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 22.5 MB/s eta 0:00:00
# ...

# %%
from ctransformers import AutoModelForCausalLM

llm = AutoModelForCausalLM.from_pretrained("TheBloke/zephyr-7B-beta-GGUF",model_file="zephyr-7b-beta.Q4_K_M.gguf")
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# zephyr-7b-beta.Q4_K_M.gguf:   0%|          | 0.00/4.37G [00:00<?, ?B/s]

# %%
llm("write some thing about llms")
# Out:
# ' and how they work in ai research\n\nllms (large language models) are a type of ai system that can generate human-like text, making them an exciting development in the field of natural language processing (nlp). Unlike traditional nlp systems, which focus on specific tasks like question answering or sentiment analysis, llms have been trained on vast amounts of text to learn the underlying structure and patterns of language.\n\nllms work by taking a sequence of words as input and outputting a probability distribution over possible sequences of words. The probability distribution is calculated using a complex mathematical function called a neural network, which consists of many interconnected nodes or "neurons." These networks can be trained on large datasets to learn how to predict the next word in a sentence given the preceding words.\n\none key feature of llms is their ability to generate coherent and fluent text that is difficult to distinguish from human writing. This is due to t
# ...

# %%
#to offload the existing models
import gc
import torch
gc.collect()
torch.cuda.empty_cache()
try:
  torch.cuda.memory_cached()
  torch.cuda.reset_peak_memory_stats()
  torch.cuda.reset_accumulated_memory_stats()
  torch.cuda.reset_max_memory_allocated()
except:
    pass
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:444: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:329: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(

# %% [markdown]
# ## **This is an alternative method of loading the model. Use the code below if your GPU is small but you still want to make use of it. you can choose how many layer you offload to gpu.We can use both the CPU and the GPU with this approach.**

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("TheBloke/zephyr-7B-beta-GGUF", model_file="zephyr-7b-beta.Q4_K_M.gguf", model_type="mistral", gpu_layers=50)

print(llm("write some thing about llms"))
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
#  and their potential impact on society
#
# llms (large language models) are a type of ai technology that have the ability to generate human-like text, potentially disrupting industries and revolutionizing society as we know it. In this blog post, we will discuss what l l ms are, their potential benefits, limitations, and impact on society in various sectors such as education, healthcare, journalism, and creativity.
#
# what are llms?
#
# llms, or large language models, are neural networks trained on vast amounts of text data to generate human-like responses to prompts. They use a technique called transformer architecture, which allows them to process long sequences of text efficiently. L l ms can understand the context and meaning of sentences, making them capable of generating coherent and relevant responses.
#
# potential benefits of llms:
#
# ...
